# %% [markdown]
# # COMM313 Computational Text Analysis for Communication Research
#
# ## Spring 2019 - Annenberg School for Communication, UPenn
# ### **Instructor**: Matthew Brook O'Donnell, Ph.D. (mbod@asc.upenn.edu)
#
# -----------

# %% [markdown]
# # Lab Session 4

# %% [markdown]
# ### Setup

# %%
import os

import requests
from bs4 import BeautifulSoup
from collections import Counter

# %%
def tokenize(text, lowercase=True, strip_chars=''):
    
    if lowercase:
        text=text.lower()
        
    rdict=str.maketrans('','',strip_chars)
    text=text.translate(rdict)
    
    tokens = text.split()
    return tokens

# %%
def make_kwic(kw, token_dict, span=4):

    kwic_line = "{: >20}||{: >40}  {}  {}"
    
    kw = kw.split() if type(kw) is str else kw

    
    
    for txt, tokens in token_dict.items():
        for pos, token in enumerate(tokens):
            
            try:
                kw_test = [tokens[pos+i]==w for i,w in enumerate(kw)]

                if sum(kw_test)==len(kw):

                        print(kwic_line.format(txt[:18],
                                               ' '.join(tokens[pos-span:pos]),
                                               ' '.join(tokens[pos:pos+len(kw)]),
                                               ' '.join(tokens[pos+len(kw):pos+span+len(kw)])))
            except:
                pass

# %% [markdown]
# ## Fairy Tale Corpus

# %%
ft_files=os.listdir('data/fairy_tales')

# %%
ft_files[10]
# Out:
# 'rumpelstiltskin.txt'

# %%
for ft in ft_files:
    print(ft)
# Out:
# the_story_of_the_youth_who_went_forth_to_learn_what_fear_was.txt
# iron_hans.txt
# the_valiant_little_tailor.txt
# the_blue_light.txt
# the_adventures_of_chanticleer_and_partlet.txt
# the_twelve_huntsmen.txt
# frederick_and_catherine.txt
# the_water_of_life.txt
# the_travelling_musicians.txt
# first_story.txt
# rumpelstiltskin.txt
# the_turnip.txt
# tom_thumb.txt
# clever_hans.txt
# the_four_clever_brothers.txt
# the_salad.txt
# the_king_of_the_golden_mountain.txt
# the_queen_bee.txt
# mother_holle.txt
# the_juniper-tree.txt
# clever_elsie.txt
# hans_in_luck.txt
# briar_rose.txt
# cat_and_mouse_in_partnership.txt
# the_three_languages.txt
# ashputtel.txt
# the_dog_and_the_sparrow.txt
# second_story.txt
# hansel_and_gretel.txt
# the_wolf_and_the_seven_little_kids.txt
# the_goose-girl.txt
# the_pink.txt
# the_willow-wren_and_the_bear.txt
# the_twelve_dancing_princesses.txt
# king_grisly-beard.txt
# rapunzel.txt
# sweetheart_roland.txt
# the_mouse_the_bird_and_the_sausage.txt
# little_red-cap_little_red_riding_hood.txt
# the_elves_and_the_shoemaker.txt
# the_golden_goose.txt
# snowdrop.txt
# the_frog-prince.txt
# snow-white_and_rose-red.txt
# the_fisherman_and_his_wife.txt
# the_little_peasant.txt
# the_old_man_and_his_grandson.txt
# the_straw_the_coal_and_the_bean.txt
# the_fox_and_the_cat.txt
# lily_and_the_lion.txt
# fundevogel.txt
# the_raven.txt
# the_robber_bridegroom.txt
# the_miser_in_the_bush.txt
# old_sultan.txt
# jorinda_and_jorindel.txt
# clever_gretel.txt
# cat-skin.txt
# the_white_snake.txt
# the_golden_bird.txt
# doctor_knowall.txt
# the_fox_and_the_horse.txt

# %%
ft_tokens={}

for ft_file in ft_files:
    
    ft = ft_file.replace('.txt','')
    
    print('Processing', ft)
    
    text = open('data/fairy_tales/{}'.format(ft_file)).read()
    
    tokens = tokenize(text, lowercase=True, strip_chars='!,?.’;:-`"')
    
    ft_tokens[ft]=tokens
# Out:
# Processing the_story_of_the_youth_who_went_forth_to_learn_what_fear_was
# Processing iron_hans
# Processing the_valiant_little_tailor
# Processing the_blue_light
# Processing the_adventures_of_chanticleer_and_partlet
# Processing the_twelve_huntsmen
# Processing frederick_and_catherine
# Processing the_water_of_life
# Processing the_travelling_musicians
# Processing first_story
# Processing rumpelstiltskin
# Processing the_turnip
# Processing tom_thumb
# Processing clever_hans
# Processing the_four_clever_brothers
# Processing the_salad
# Processing the_king_of_the_golden_mountain
# Processing the_queen_bee
# Processing mother_holle
# Processing the_juniper-tree
# Processing clever_elsie
# Processing hans_in_luck
# Processing briar_rose
# Processing cat_and_mouse_in_partnership
# Processing the_three_languages
# Processing ashputtel
# Processing the_dog_and_the_sparrow
# Processing second_story
# Processing hansel_and_gretel
# Processing the_wolf_and_the_seven_little_kids
# Processing the_goose-girl
# Processing the_pink
# Processing the_willow-wren_and_the_bear
# Processing the_twelve_dancing_princesses
# Processing king_grisly-beard
# Processing rapunzel
# Processing sweetheart_roland
# Processing the_mouse_the_bird_and_the_sausage
# Processing little_red-cap_little_red_riding_hood
# Processing the_elves_and_the_shoemaker
# Processing the_golden_goose
# Processing snowdrop
# Processing the_frog-prince
# Processing snow-white_and_rose-red
# Processing the_fisherman_and_his_wife
# Processing the_little_peasant
# Processing the_old_man_and_his_grandson
# Processing the_straw_the_coal_and_the_bean
# Processing the_fox_and_the_cat
# Processing lily_and_the_lion
# Processing fundevogel
# Processing the_raven
# Processing the_robber_bridegroom
# Processing the_miser_in_the_bush
# Processing old_sultan
# Processing jorinda_and_jorindel
# Processing clever_gretel
# Processing cat-skin
# Processing the_white_snake
# Processing the_golden_bird
# Processing doctor_knowall
# Processing the_fox_and_the_horse

# %%
toks=ft_tokens['old_sultan']

freq_list = Counter(toks)

# %%
freq_list.most_common(20)
# Out:
# [('the', 59),
#  ('and', 53),
#  ('to', 25),
#  ('his', 21),
#  ('a', 17),
#  ('he', 16),
#  ('sultan', 15),
#  ('him', 15),
#  ('wolf', 13),
#  ('was', 12),
#  ('it', 11),
#  ('you', 11),
#  ('they', 11),
#  ('of', 10),
#  ('so', 10),
#  ('said', 9),
#  ('for', 9),
#  ('with', 9),
#  ('in', 9),
#  ('be', 9)]

# %%
make_kwic(['old','woman'], ft_tokens)
# Out:
#       the_blue_light||                      again next day the  old woman  took him to the
#            the_salad||                        came up a little  old woman  and said to him
#            the_salad||                     happens just as the  old woman  said then he shot
#            the_salad||                     huntsman did as the  old woman  told him cut open
#            the_salad||                    the windows stood an  old woman  with a very beautiful
#            the_salad||                      about them now the  old woman  was a witch and
#            the_salad||                     she wished then the  old woman  said ‘now is the
#   the_elves_and_the_||                       to ply with their  little  fingers stitching and rapping
#   the_elves_and_the_||                 to the shoemaker ‘these  little  wights have made us
#   the_elves_and_the_||                          each of them a  little  pair of shoes the
#   the_elves_and_the_||                       to watch what the  little  elves would do about
#     the_golden_goose||                         forest he met a  little  greyhaired old man who
#     the_golden_goose||                         and he left the  little  man standing and went
#     the_golden_goose||                        and this was the  little  grey mans doing after
#     the_golden_goose||                      bottle of wine the  little  old grey man met
#     the_golden_goose||                         and he left the  little  man standing and went
#     the_golden_goose||                       to the forest the  little  old grey man met
#     the_golden_goose||                      and after that the  little  man said ‘since you
#     the_golden_goose||                      the roots then the  little  man took leave of
#     the_golden_goose||                 dummling thought of the  little  grey man who could
#     the_golden_goose||                       and there sat the  little  grey man to whom
#             snowdrop||                     said ‘would that my  little  daughter may be as
#             snowdrop||                  windowframe and so the  little  girl really did grow
#             snowdrop||                         to rest for her  little  feet would carry her
#             snowdrop||                    and there were seven  little  plates seven little loaves
#             snowdrop||               seven little plates seven  little  loaves and seven little
#             snowdrop||                 little loaves and seven  little  glasses with wine in
#             snowdrop||                    the wall stood seven  little  beds as she was
#             snowdrop||                     hungry she picked a  little  piece of each loaf
#             snowdrop||                        and drank a very  little  wine out of each
#             snowdrop||                       she tried all the  little  beds but one was
#             snowdrop||                     now they were seven  little  dwarfs that lived among
#             snowdrop||                           lace and in a  little  time she began to
#             snowdrop||                         in vain for the  little  girl seemed quite dead
#             snowdrop||                          a visit to the  little  dwarfs who had been
#      the_frog-prince||                       water and after a  little  while he came up
#      the_frog-prince||                          the door and a  little  voice cried out and
#   snow-white_and_ros||                  to them trustfully the  little  hare would eat a
#   snow-white_and_ros||              rosered kept their mothers  little  cottage so neat that
#   snow-white_and_ros||                        to warm myself a  little  beside you ‘poor bear
#   snow-white_and_ros||                            of my coat a  little  so they brought the
#   snow-white_and_ros||                        the tree and the  little  fellow was jumping about
#   snow-white_and_ros||                           are you up to  little  man asked rosered ‘you
#   snow-white_and_ros||                           tree to get a  little  wood for cooking the
#   snow-white_and_ros||                    wood for cooking the  little  bit of food that
#   snow-white_and_ros||                          pull me in the  little  man had been sitting
#   snow-white_and_ros||                           but it was of  little  good for he was
#   snow-white_and_ros||                       tight hold of the  little  man and pulled against
#   snow-white_and_ros||                     with such a slender  little  fellow as i you
#   the_fisherman_and_||                          we want a snug  little  cottage the fisherman did
#   the_fisherman_and_||                        and wants a snug  little  cottage ‘go home then
#   the_fisherman_and_||                          of a nice trim  little  cottage ‘come in come
#   the_fisherman_and_||                     cottage there was a  little  garden planted with all
#   the_fisherman_and_||                         giant down to a  little  dwarf no bigger than
#   the_fisherman_and_||                     heavens there was a  little  piece of blue sky
#   the_little_peasant||                                          little  peasant there was a
#   the_little_peasant||                    whom they called the  little  peasant he had not
#   the_little_peasant||                    being driven out the  little  peasant called the cowherd
#   the_little_peasant||                          ‘look i have a  little  calf there but it
#   the_little_peasant||                     among the grass the  little  calf always remained standing
#   the_little_peasant||                         my arms but the  little  peasant stood at his
#   the_little_peasant||                      and waited for his  little  calf and when the
#   the_little_peasant||                         with us but the  little  peasant said ‘oh but
#   the_little_peasant||                        away and now the  little  peasant and his wife
#   the_little_peasant||                       the fifth but the  little  peasant said ‘first we
#   the_little_peasant||                  the mayor the innocent  little  peasant was unanimously sentenced
#   the_little_peasant||                        look about you a  little  down below there and
#   the_little_peasant||                    sky which are called  little  lambs and they were
#   the_old_man_and_hi||                   sitting thus when the  little  grandson of four years
#   the_old_man_and_hi||                          ‘i am making a  little  trough answered the child
#   the_old_man_and_hi||                          he did spill a  little  of anything
#   the_straw_the_coal||                          they came to a  little  brook and as there
#    lily_and_the_lion||                    took with them their  little  child and she chose
#           fundevogel||                       screaming as if a  little  child were there he
#           fundevogel||                           top of this a  little  child was sitting for
#           fundevogel||                        the forest but a  little  rosebush with one rose
#            the_raven||                         queen who had a  little  daughter still too young
#            the_raven||                         i should have a  little  peace scarcely were the
#            the_raven||                          lay down for a  little  while fully determined however
#            the_raven||                       and then seeing a  little  glimmer ahead of him
#            the_raven||                      he built himself a  little  hut and there he
#   the_robber_bridegr||                  still remaining on the  little  finger of the murdered
#   the_miser_in_the_b||                   singing and dancing a  little  dwarf met him and
#   the_miser_in_the_b||                        come to said the  little  man ‘full threepence replied
#   the_miser_in_the_b||                          he had and the  little  dwarf said in return
#           old_sultan||                     and they take their  little  child with them and
#           old_sultan||                        with the child a  little  way the shepherd and
#           old_sultan||                    and carried the poor  little  thing back to his
#           old_sultan||                           one of them a  little  the cat seeing something
#             cat-skin||                       they showed her a  little  corner under the staircase
#             cat-skin||                               i go up a  little  while and see what
#             cat-skin||                       then she took her  little  lamp and went into
#             cat-skin||                        had run into her  little  cabin pulled off her
#             cat-skin||                       the cabin for her  little  golden ring and put
#             cat-skin||                          she ran to her  little  cabin washed herself quickly
#             cat-skin||                     she sprang into her  little  cabin and made herself
#             cat-skin||                      she could into her  little  cabin under the stairs
#             cat-skin||                        cloak fell off a  little  on one side and
#      the_white_snake||                             he cut of a  little  bit and put it
#      the_white_snake||                 a strange whispering of  little  voices outside his window
#      the_white_snake||                          and go about a  little  when his request was
#      the_golden_bird||                          had gone but a  little  way he came to
#      the_golden_bird||                       and had done very  little  the fox came and
#       doctor_knowall||               one daughter although the  little  girl was very pretty
#       doctor_knowall||                      sons with his dear  little  daughter who soon became
#       doctor_knowall||                           of it but the  little  girl mourned sadly about
#       doctor_knowall||                          with her but a  little  ring which her father
#       doctor_knowall||                      should be hungry a  little  pitcher of water in
#       doctor_knowall||                        be thirsty and a  little  stool to rest upon
#       doctor_knowall||                        sat upon his own  little  stool but the morning
#       doctor_knowall||                          and gave her a  little  piece of wood and
#       doctor_knowall||                       you have not this  little  piece of wood you
#       doctor_knowall||                  your brothers live the  little  girl took the piece
#       doctor_knowall||                              it up in a  little  cloth and went on
#       doctor_knowall||                        she felt for the  little  piece of wood but
#       doctor_knowall||          glassmountain so this faithful  little  sister took a knife
#       doctor_knowall||                         and cut off her  little  finger that was just
#       doctor_knowall||                           she went in a  little  dwarf came up to
#       doctor_knowall||                         step in now the  little  dwarf was getting their
#       doctor_knowall||                   their food upon seven  little  plates and their drink
#       doctor_knowall||                    their drink in seven  little  glasses and set them
#       doctor_knowall||                         and out of each  little  plate their sister ate
#       doctor_knowall||                         and out of each  little  glass she drank a
#       doctor_knowall||                    and looked for their  little  plates and glasses then
#       doctor_knowall||                       has eaten from my  little  plate and who has
#       doctor_knowall||                      drinking out of my  little  glass ‘caw caw well
#       doctor_knowall||                        said ‘o that our  little  sister would but come
#       doctor_knowall||                        be free when the  little  girl heard this (for
#   the_fox_and_the_ho||                   the wood seeking some  little  shelter from the cold
#   the_fox_and_the_ho||                          said to him ‘a  little  way off lies a

# %%
make_kwic('once upon a time', ft_tokens)
# Out:
#            iron_hans||                     iron hans there was  once upon a time  a king who had
#       the_blue_light||                    blue light there was  once upon a time  a soldier who for
#          first_story||                   first story there was  once upon a time  an old fox with
#        the_queen_bee||                      bee two kings sons  once upon a time  went into the world
#         mother_holle||                                          once upon a time  there was a widow
#           briar_rose||                        a king and queen  once upon a time  reigned in a country
#   the_wolf_and_the_s||                   little kids there was  once upon a time  an old goat who
#             the_pink||                      the pink there was  once upon a time  a queen to whom
#    king_grisly-beard||                      made sport of them  once upon a time  the king held a
#    sweetheart_roland||             sweetheart roland there was  once upon a time  a woman who was
#   the_mouse_the_bird||                    bird and the sausage  once upon a time  a mouse a bird
#   little_red-cap_lit||                [little red riding hood]  once upon a time  there was a dear
#       doctor_knowall||                doctor knowall there was  once upon a time  a poor peasant called

# %% [markdown]
# ## Loop and filter idiom

# %%
little_what=[]

for ft in ft_tokens:
    tokens = ft_tokens[ft]
    
    for i, t in enumerate(tokens):
        if t=='little':
            little_what.append(tokens[i+1])

# %%
little_what
# Out:
# ['the',
#  'farther',
#  'for',
#  'cousin',
#  'cousin',
#  'and',
#  'cousin',
#  'fishes',
#  'cap',
#  'cap',
#  'was',
#  'cap',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'respect',
#  'better',
#  'man',
#  'mite',
#  'tailor',
#  'man',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'tailor',
#  'to',
#  'black',
#  'man',
#  'man',
#  'man',
#  'man',
#  'black',
#  'man',
#  'carriage',
#  'way',
#  'hearse',
#  'hillock',
#  'while',
#  'old',
#  'old',
#  'ugly',
#  'loaves',
#  'friend',
#  'dwarf',
#  'way',
#  'frightened',
#  'eyes',
#  'cat',
#  'man',
#  'friend',
#  'man',
#  'child',
#  'child',
#  'man',
#  'gentleman',
#  'hut',
#  'dwarf',
#  'does',
#  'friend',
#  'man',
#  'man',
#  'turnips',
#  'longer',
#  'while',
#  'space',
#  'matters',
#  'boy',
#  'as',
#  'fellow',
#  'man',
#  'too',
#  'urchin',
#  'man',
#  'man',
#  'urchin',
#  'way',
#  'urchin',
#  'man',
#  'man',
#  'man',
#  'son',
#  'bundles',
#  'red',
#  'old',
#  'time',
#  'i',
#  'of',
#  'of',
#  'roughlooking',
#  'man',
#  'plot',
#  'boy',
#  'boy',
#  'money',
#  'heinel',
#  'uglylooking',
#  'trouble',
#  'man',
#  'black',
#  'old',
#  'insignificant',
#  'dwarf',
#  'grey',
#  'dwarfs',
#  'dwarf',
#  'farther',
#  'house',
#  'while',
#  'child',
#  'daughter',
#  'daughter',
#  'daughter',
#  'daughters',
#  'boy',
#  'boys',
#  'marleen',
#  'marleen',
#  'boy',
#  'marleen',
#  'marleen',
#  'son',
#  'son',
#  'son',
#  'son',
#  'son',
#  'son',
#  'marleen',
#  'marleen',
#  'marleen',
#  'son',
#  'marleen',
#  'son',
#  'marleen',
#  'marleen',
#  'brother',
#  'marleen',
#  'bells',
#  'faster',
#  'the',
#  'and',
#  'fish',
#  'fish',
#  'fish',
#  'girl',
#  'daughter',
#  'princess',
#  'door',
#  'thing',
#  'room',
#  'mouse',
#  'mouse',
#  'son',
#  'girl',
#  'girl',
#  'bird',
#  'maiden',
#  'birds',
#  'doves',
#  'maiden',
#  'birds',
#  'doves',
#  'lamp',
#  'grey',
#  'grey',
#  'dove',
#  'dove',
#  'dirty',
#  'while',
#  'way',
#  'pointed',
#  'to',
#  'coat',
#  'pocket',
#  'sister',
#  'piece',
#  'white',
#  'cat',
#  'hill',
#  'piece',
#  'until',
#  'sister',
#  'sister',
#  'pigeon',
#  'pigeon',
#  'by',
#  'threw',
#  'we',
#  'sister',
#  'house',
#  'house',
#  'of',
#  'house',
#  'house',
#  'beds',
#  'house',
#  'stable',
#  'stable',
#  'bone',
#  'sister',
#  'stable',
#  'duck',
#  'duck',
#  'duck',
#  'kids',
#  'kids',
#  'kids',
#  'mother',
#  'kids',
#  'mother',
#  'kid',
#  'knife',
#  'brook',
#  'time',
#  'goosegirl',
#  'goosegirl',
#  'older',
#  'hind',
#  'while',
#  'branch',
#  'boats',
#  'dirty',
#  'window',
#  'window',
#  'room',
#  'redcap',
#  'girl',
#  'cap',
#  'redcap',
#  'redcap',
#  'redcap',
#  'redcap',
#  'redcap',
#  'redcap',
#  'redcap',
#  'redcap',
#  'redcap',
#  'birds',
#  'redcap',
#  'redcap',
#  'redcap',
#  'girl',
#  'redcap',
#  'naked',
#  'fingers',
#  'wights',
#  'pair',
#  'elves',
#  'greyhaired',
#  'man',
#  'grey',
#  'old',
#  'man',
#  'old',
#  'man',
#  'man',
#  'grey',
#  'grey',
#  'daughter',
#  'girl',
#  'feet',
#  'plates',
#  'loaves',
#  'glasses',
#  'beds',
#  'piece',
#  'wine',
#  'beds',
#  'dwarfs',
#  'time',
#  'girl',
#  'dwarfs',
#  'while',
#  'voice',
#  'hare',
#  'cottage',
#  'beside',
#  'so',
#  'fellow',
#  'man',
#  'wood',
#  'bit',
#  'man',
#  'good',
#  'man',
#  'fellow',
#  'cottage',
#  'cottage',
#  'cottage',
#  'garden',
#  'dwarf',
#  'piece',
#  'peasant',
#  'peasant',
#  'peasant',
#  'calf',
#  'calf',
#  'peasant',
#  'calf',
#  'peasant',
#  'peasant',
#  'peasant',
#  'peasant',
#  'down',
#  'lambs',
#  'grandson',
#  'trough',
#  'of',
#  'brook',
#  'child',
#  'child',
#  'child',
#  'rosebush',
#  'daughter',
#  'peace',
#  'while',
#  'glimmer',
#  'hut',
#  'finger',
#  'dwarf',
#  'man',
#  'dwarf',
#  'child',
#  'way',
#  'thing',
#  'the',
#  'corner',
#  'while',
#  'lamp',
#  'cabin',
#  'golden',
#  'cabin',
#  'cabin',
#  'cabin',
#  'on',
#  'bit',
#  'voices',
#  'when',
#  'way',
#  'the',
#  'girl',
#  'daughter',
#  'girl',
#  'ring',
#  'pitcher',
#  'stool',
#  'stool',
#  'piece',
#  'piece',
#  'girl',
#  'cloth',
#  'piece',
#  'sister',
#  'finger',
#  'dwarf',
#  'dwarf',
#  'plates',
#  'glasses',
#  'plate',
#  'glass',
#  'plates',
#  'plate',
#  'glass',
#  'sister',
#  'girl',
#  'shelter',
#  'way']

# %%
Counter(little_what).most_common(15)
# Out:
# [('tailor', 32),
#  ('man', 28),
#  ('redcap', 14),
#  ('marleen', 11),
#  ('girl', 11),
#  ('son', 10),
#  ('dwarf', 9),
#  ('while', 8),
#  ('peasant', 8),
#  ('way', 7),
#  ('child', 7),
#  ('daughter', 7),
#  ('sister', 7),
#  ('piece', 7),
#  ('old', 6)]

# %%
old_what=[]


for ft in ft_tokens:
    tokens = ft_tokens[ft]
    
    for i, t in enumerate(tokens):
        if t=='old':
            old_what.append(tokens[i+1])

# %%
Counter(old_what).most_common()
# Out:
# [('woman', 54),
#  ('man', 20),
#  ('king', 14),
#  ('mr', 7),
#  ('witch', 6),
#  ('cook', 6),
#  ('fox', 5),
#  ('and', 4),
#  ('tower', 3),
#  ('lady', 3),
#  ('grey', 3),
#  ('sultan', 3),
#  ('castle', 2),
#  ('song', 2),
#  ('kings', 2),
#  ('ones', 2),
#  ('one', 2),
#  ('womans', 2),
#  ('the', 2),
#  ('folks', 2),
#  ('goat', 2),
#  ('sinner', 2),
#  ('dame', 2),
#  ('grandfather', 2),
#  ('sanna', 2),
#  ('fairy', 2),
#  ('rags', 1),
#  ('however', 1),
#  ('mans', 1),
#  ('cheese', 1),
#  ('dry', 1),
#  ('key', 1),
#  ('noble', 1),
#  ('mousehole', 1),
#  ('shape', 1),
#  ('ass', 1),
#  ('iron', 1),
#  ('frock', 1),
#  ('but', 1),
#  ('world', 1),
#  ('friend', 1),
#  ('beast', 1),
#  ('whoever', 1),
#  ('nail', 1),
#  ('palace', 1),
#  ('as', 1),
#  ('soldier', 1),
#  ('mop', 1),
#  ('custom', 1),
#  ('grandmother', 1),
#  ('tree', 1),
#  ('she', 1),
#  ('pedlar', 1),
#  ('enemy', 1),
#  ('withered', 1),
#  ('acquaintance', 1),
#  ('mother', 1),
#  ('began', 1),
#  ('miser', 1),
#  ('cushion', 1),
#  ('shepherds', 1),
#  ('rogue', 1),
#  ('threelegged', 1),
#  ('walls', 1),
#  ('forms', 1),
#  ('fairys', 1),
#  ('ravens', 1),
#  ('leathern', 1),
#  ('to', 1),
#  ('servant', 1),
#  ('horse', 1)]

# %%
what_girl=[]
what_boy=[]
small_what=[]

for ft in ft_tokens:
    tokens = ft_tokens[ft]
    
    for i, t in enumerate(tokens):
        if t=='girl':
            what_girl.append(tokens[i-1])
            
        if t=='boy':
            what_boy.append(tokens[i-1])
            
        if t=='small':
            small_what.append(tokens[i+1])

# %%
Counter(what_boy).most_common(10)
# Out:
# [('the', 44),
#  ('little', 5),
#  ('gardeners', 4),
#  ('a', 3),
#  ('his', 2),
#  ('‘your', 1),
#  ('poor', 1),
#  ('innocent', 1)]

# %%
Counter(what_girl).most_common(10)
# Out:
# [('the', 28),
#  ('little', 11),
#  ('lazy', 3),
#  ('poor', 3),
#  ('silly', 2),
#  ('pretty', 2),
#  ('a', 2),
#  ('young', 2),
#  ('good', 1),
#  ('strange', 1)]

# %%
my_list=[]

# %%
my_list.append('item1')

# %%
my_list
# Out:
# ['item1']

# %%
my_list.append('item1', 'item2')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-7e124c09b342> in <module>()
# ----> 1 my_list.append('item1', 'item2')
#
# TypeError: append() takes exactly one argument (2 given)

# %%
my_list.append(['item1', 'item2'])

# %%
my_list
# Out:
# ['item1', ['item1', 'item2']]

# %%
my_list2 = ['item1']

# %%
my_list2.extend(['item2','item3'])

# %%
my_list2
# Out:
# ['item1', 'item2', 'item3']

# %%
loved_what = []

for ft in ft_tokens:
    tokens = ft_tokens[ft]
    
    for i, t in enumerate(tokens):
        if t=='loved':
            loved_what.extend(tokens[i+1:i+5])

# %%
Counter(loved_what).most_common(20)
# Out:
# [('loved', 24),
#  ('all', 10),
#  ('me', 8),
#  ('best', 8),
#  ('of', 8),
#  ('her', 5),
#  ('and', 4),
#  ('dearly', 4),
#  ('very', 3),
#  ('much', 3),
#  ('each', 3),
#  ('other', 3),
#  ('so', 2),
#  ('she', 2),
#  ('you', 2),
#  ('the', 2),
#  ('with', 2),
#  ('was', 2),
#  ('his', 1),
#  ('wife', 1)]

# %%
make_kwic('loved',ft_tokens)
# Out:
#   the_story_of_the_y||                     much the young king  loved  his wife and however
#   the_twelve_huntsme||                         a bride whom he  loved  very much and when
#   the_twelve_huntsme||               former betrothed whom she  loved  so dearly then she
#            the_salad||                       will for i always  loved  you very much your
#         mother_holle||                 lazy the mother however  loved  the ugly and lazy
#     the_juniper-tree||                 and beautiful wife they  loved  each other dearly but
#     the_juniper-tree||                      as snow the mother  loved  her daughter very much
#     the_juniper-tree||                      was gone my sister  loved  me best of all
#     the_juniper-tree||                      was gone my sister  loved  me best of all
#     the_juniper-tree||                      was gone my sister  loved  me best of all
#     the_juniper-tree||                      was gone my sister  loved  me best of all
#     the_juniper-tree||                  and listened my sister  loved  me best of all
#     the_juniper-tree||                      was gone my sister  loved  me best of all
#     the_juniper-tree||                       the air my sister  loved  me best of all
#     the_juniper-tree||                       if dead my sister  loved  me best of all
#           briar_rose||                   everyone who knew her  loved  her it happened that
#   the_wolf_and_the_s||                   seven little kids and  loved  them with all the
#       the_goose-girl||                beautiful and her mother  loved  her dearly and was
#             the_pink||                 two played together and  loved  each other with all
#    king_grisly-beard||                  there because i really  loved  you i am also
#             rapunzel||                         die the man who  loved  her thought ‘sooner than
#    sweetheart_roland||                        and this one she  loved  because she was her
#   little_red-cap_lit||                     little girl who was  loved  by everyone who looked
#           fundevogel||                away fundevogel and lina  loved  each other so dearly

# %%
loved_what
# Out:
# ['his',
#  'wife',
#  'and',
#  'however',
#  'very',
#  'much',
#  'and',
#  'when',
#  'so',
#  'dearly',
#  'then',
#  'she',
#  'you',
#  'very',
#  'much',
#  'your',
#  'the',
#  'ugly',
#  'and',
#  'lazy',
#  'each',
#  'other',
#  'dearly',
#  'but',
#  'her',
#  'daughter',
#  'very',
#  'much',
#  'me',
#  'best',
#  'of',
#  'all',
#  'me',
#  'best',
#  'of',
#  'all',
#  'me',
#  'best',
#  'of',
#  'all',
#  'me',
#  'best',
#  'of',
#  'all',
#  'me',
#  'best',
#  'of',
#  'all',
#  'me',
#  'best',
#  'of',
#  'all',
#  'me',
#  'best',
#  'of',
#  'all',
#  'me',
#  'best',
#  'of',
#  'all',
#  'her',
#  'it',
#  'happened',
#  'that',
#  'them',
#  'with',
#  'all',
#  'the',
#  'her',
#  'dearly',
#  'and',
#  'was',
#  'each',
#  'other',
#  'with',
#  'all',
#  'you',
#  'i',
#  'am',
#  'also',
#  'her',
#  'thought',
#  '‘sooner',
#  'than',
#  'because',
#  'she',
#  'was',
#  'her',
#  'by',
#  'everyone',
#  'who',
#  'looked',
#  'each',
#  'other',
#  'so',
#  'dearly']

# %% [markdown]
# ### Making a corpus of _AirPods_ web pages

# %% [markdown]
#  * https://bgr.com/2016/12/28/airpods-review-running-walking-sound-quality-more/
#  * https://www.carlytheprepster.com/2018/01/i-love-my-airpods.html
#  * https://www.tomsguide.com/us/apple-airpods-worth-buying,review-5837.html
#  * https://www.thecut.com/2018/04/apple-airpod-headphones-new-york-subway-trend.html

# %%
headers = {'User-Agent': 'Mozilla 5.0'}

# %%
page_text = requests.get('https://www.tomsguide.com/us/apple-airpods-worth-buying,review-5837.html', headers=headers)

# %%
page_text.text
# Out:
# '<!DOCTYPE html>\n<html lang="en" xmlns="https://www.w3.org/1999/xhtml" xmlns:og="//opengraphprotocol.org/schema/" xmlns:fb="https://www.facebook.com/2008/fbml" class="prod body tgu-site en_us desktop">\n    <head>\n        <!-- META TAGS -->\n        <meta charset="UTF-8"/>\n                                                                                                                                                                \n                            <title>How I Finally Learned to Love Apple\'s AirPods</title>\n        <link rel="canonical" href="https://www.tomsguide.com/us/apple-airpods-worth-buying,review-5837.html" itemprop="url" />                        \n\n        <head itemscope itemtype="https://schema.org/WebSite">\n        <head itemprop="name" content="Tom\'s Guide">\n        <meta name="content-language" content="en" />\n        <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1" />\n        <meta name="robots" content="index,follow" />\n        <meta name="description" content="I spent years ignoring AirPods, only to find that these headphones are the best thing Apple&#039;s put out in years." />\n        <meta property="og:url" content="https://www.tomsguide.com/us/apple-airpods-worth-buying,review-5837.html" />\n        <meta property="og:title" content="How I Finally Learned to Love Apple\'s AirPods" />\n        <meta property="og:description" content="I spent years ignoring AirPods, only to find that these headphones are the best thing Apple&#039;s put out in years." />\n        <meta property="og:site_name" content="Tom\'s Guide" />\n        <meta property="og:image" content="https://img.purch.com/o/aHR0cDovL21lZGlhLmJlc3RvZm1pY3JvLmNvbS9BL0MvODAzODkyL29yaWdpbmFsL2hlbnJ5LWFpci1wb2RzLTAwMS5qcGc=" />        <meta property="og:image:width" content="560" />        <meta property="og:image:height" content="300" />                        <meta property="article:section" content="apple" />        <meta property="og:type" content="article" />\n        <meta property="fb:page_id" content="22359506999" />\n        <meta name="twitter:card" content="product">\n                <meta name="twitter:site" content="@tomsguide">\n                        <meta name="twitter:title" content="How I Finally Learned to Love Apple\'s AirPods">\n        <meta name="twitter:image" content="https://img.purch.com/w/500/aHR0cDovL21lZGlhLmJlc3RvZm1pY3JvLmNvbS9BL0MvODAzODkyL29yaWdpbmFsL2hlbnJ5LWFpci1wb2RzLTAwMS5qcGc=">        <meta name="twitter:description" content="I spent years ignoring AirPods, only to find that these headphones are the best thing Apple&#039;s put out in years.">\n        <meta property="notification-title" content="Why Apple&#039;s AirPods Rock" />        <meta property="notification-description" content="Audio excellence worth the cash." />        \n<meta property="article:published_time" class="flipboard-date" content="2018-10-14" /><meta property="article:tag" content="Headphones"/><meta property="main_section" content="Opinion"/><meta name="twitter:creator" content="@henrytcasey">\n\n    <link rel="apple-touch-icon" sizes="57x57" href="/medias/favicon/apple-touch-icon-57x57.png?v=kPPAMMXoY2">\n<link rel="apple-touch-icon" sizes="60x60" href="/medias/favicon/apple-touch-icon-60x60.png?v=kPPAMMXoY2">\n<link rel="apple-touch-icon" sizes="72x72" href="/medias/favicon/apple-touch-icon-72x72.png?v=kPPAMMXoY2">\n<link rel="apple-touch-icon" sizes="76x76" href="/medias/favicon/apple-touch-icon-76x76.png?v=kPPAMMXoY2">\n<link rel="apple-touch-icon" sizes="114x114" href="/medias/favicon/apple-touch-icon-114x114.png?v=kPPAMMXoY2">\n<link rel="apple-touch-icon" sizes="120x120" href="/medias/favicon/apple-touch-icon-120x120.png?v=kPPAMMXoY2">\n<link rel="apple-touch-icon" sizes="144x144" href="/medias/favicon/apple-touch-icon-144x144.png?v=kPPAMMXoY2">\n<link rel="apple-touch-icon" sizes="152x152" href="/medias/favicon/ ...

# %% [markdown]
# ### LexisNexis _AirPods_ export
#
# * Look at the file `LN_AirPods.txt`
#
# * Can we split it into a series of articles like we did with the Grimm's Fairy Tales file
