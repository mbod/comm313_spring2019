# %% [markdown]
# # What is a corpus?
#
# ### COMM313 Spring 2019 (01/28/19)

# %% [markdown]
# ## Readings
#
#
# * Baker, P. (2006) Using Corpora in Discourse Analysis. London: Continuum - **Read Chs. 1&2**
# * NLTK Book Ch. 1 (sections 1, 2 & 4 ) http://www.nltk.org/book/ch01.html
#
#
# ### Key points
#
# * Baker Ch. 1
#     * corpora and corpus techniques can reveal **patterns of language usage** that can reveal how
#         * __meaning__,
#         * __effect__ (function)
#         * __position__ (ideology)
#
#       are acheived in discourse (text)
#
#     * **discourses** are ways of constructing reality
#     * corpus linguistics relies on both _quantitative_ and _qualtitative_ methods to interpret text
#     * advantages of corpus methods for discourse analysis
#         * reduces researcher bias
#         * reveal the incrementental/additive nature of discourse
#         * trace the changing/resistant nature of discourse
#         * triangulation of observations from other methods

# %% [markdown]
# ## Corpus
#
# is a collection of texts of a **particular language or language variety** that are
#
# 1. machine-readable
# 2. authentic
# 3. sampled
# 4. representative
#
#
# * "collection of texts selected and put together in a principled way" (Johansson 1998)
#
# * "built according to explicit design criteria for a specific purpose" (Atkins 1992)

# %% [markdown]
# ## Types of corpora
#
# ### Topic/content
# 1. **Specialized**
#     * represents specific discourse type/topic
# 2. **General / Reference**
#     * broad sampling of language type
#
# ### Time frame
# 1. **Synchronic**
#    * snapshot of one particular instance
# 2. **Diachronic**
#    * changes over time
#
# ### Other dimensions
#
# * **Matched/Comparable**
#     * designed to allow specific comparisons
#
# * **Production vs Reception**
#     * PRODUCTION: texts representing what broad range of people are saying about a topic
#     * RECEPTION: texts representing the dominant discourses on a topic that people are likely to be exposed to
#
# * **Annotated vs Plain (unannotated)**

# %% [markdown]
# ### Design characteristics
#
# * **representativeness**
#     * representativeness refers to the extent to which a *sample* includes the full range of *variability* in a population (Biber 1993)
#
#     * "fluid concept" (Xiao 2010) dependent on research question:
#         * investigating contemporary general English
#             * 1960s corpus of books?
#             * 2010s corpus of newspapers?
#         * investigating newspaper discourse
#             * New York Times archive?
#
# * **balance**
#
#     * for a general corpus relates to the range of genres/text types that should be included and the amount of each type
#     * for a specialized corpus relates _closure/saturation_ and range of authors, text sources, etc.

# %% [markdown]
# ## Using corpora for discourse analysis
#
#
# ### 1. Collect a corpus representing the discourse of interest and explore patterns (_Specialized Discourse Corpus_)
# ![](specialized_corpus.png)
#
# ### 2. Start from a single text and investigate language in it at scale
#
# ![](one_text_to_corpus.png)

# %% [markdown]
# ## 1. Examining a specialized discourse corpus
#
# * Using one of the corpora included in the _NLTK_ as sample 'texts' for illustration.

# %%
# %matplotlib inline

# %%
import graphviz
import math
from nltk.book import *
import os
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# #### The _Personals Corpus_
#
# * A small corpus of personal ads from newspapers, e.g.
#
# ```
#     25 SEXY MALE, seeks attrac older single lady, for discreet encounters.
#
#     HANDSOME BUSINESSMAN Tall, slim, independant, under standing, mid 50s, looking for classy lady who
#     wants to retain her privacy, still retain her independance and is looking for a special private relationship.
#
#     HERE I AM PICK ME! PICK ME! Now that I have your attention Im a 35 y.o. 59 attractive guy,
#     non-smoker/social drinker, fit and active, is seeking a slim-medium lady for friendship/relationship .
#
# ```

# %% [markdown]
# * The _NLTK_ wraps these example texts into a Python _object_ to make it easy to do some quick exploration of the corpus.
#
#
# * The _Personals Corpus_ is referenced by default with a named pointer `text8`.

# %% [markdown]
# * Check the `.name` attribute of the object

# %%
text8.name
# Out:
# 'Personals Corpus'

# %% [markdown]
# ### Things we can do with the `text` object
#
#
# * `text8.vocab()`
# * `text8.dispersion_plot()`
# * `text8.concordance()`
# * `text8.collocations()`

# %% [markdown]
# #### Examine the vocabulary
#
# * Top 50 most frequent words in the corpus
#
# * Corpus is tokenized as a single list with punctuation included as separate tokens.

# %%
personal_ads_freq_dist=text8.vocab()
personal_ads_freq_dist.most_common(50)
# Out:
# [(',', 539),
#  ('.', 353),
#  ('/', 110),
#  ('for', 99),
#  ('and', 74),
#  ('to', 74),
#  ('lady', 68),
#  ('-', 66),
#  ('seeks', 60),
#  ('a', 52),
#  ('with', 44),
#  ('S', 36),
#  ('ship', 33),
#  ('&', 30),
#  ('relationship', 29),
#  ('fun', 28),
#  ('in', 27),
#  ('slim', 27),
#  ('build', 27),
#  ('o', 26),
#  ('s', 24),
#  ('y', 23),
#  ('smoker', 23),
#  ('50', 23),
#  ('non', 22),
#  ('I', 22),
#  ('movies', 22),
#  ('good', 21),
#  ('honest', 20),
#  ('dining', 19),
#  ('out', 19),
#  ('rship', 18),
#  ('looking', 18),
#  ('like', 18),
#  ('age', 17),
#  ('attractive', 17),
#  ('who', 17),
#  ('friendship', 17),
#  ('40', 16),
#  ('45', 16),
#  ('35', 16),
#  ('Looking', 16),
#  ('5', 16),
#  ('MALE', 15),
#  ('times', 15),
#  ('male', 15),
#  ('meet', 15),
#  ('life', 15),
#  ('seeking', 14),
#  ('r', 14)]

# %% [markdown]
# #### Plot distribution of words across the corpus
#
# * This kind of plot tends to be use for comparison of longer individual texts (or chapters within a book etc)
#
#
# * Because the _Personals Corpus_ is just a single "text" it is difficult to clearly interpret the plots. However, each ad is about the same length so we are looking for consistent distribution of a word across the x-axis (Word Offset). We can also include a period (`.`) as an item in the plot as they are likely to occur in every single ad at least once.

# %%
text8.dispersion_plot(['man','lady','woman','guy', 'male', 'female', '.'])

# %%
text8.dispersion_plot(['male','female','seeking', 'seeks', 'looking', '.'])

# %% [markdown]
# * Try some other plots of your own

# %% [markdown]
# #### Concordance listings from a keyword
#
# * Concordance listing provides more context around a single keyword. It allows you to identify patterns of repeated word use.

# %%
text8.concordance('woman')
# Out:
# Displaying 11 of 11 matches:
# at home . Seeking an honest , caring woman , slim or med . build , who enjoys t
# thy man 37 like to meet full figured woman for relationship . 48 slim , shy , S
# rry . MALE 58 years old . Is there a Woman who would like to spend 1 weekend a
#  other interests . Seeking Christian Woman for fship , view to rship . SWM 45 D
# ALE 60 - burly beared seeks intimate woman for outings n / s s / d F / ston / P
# ington . SCORPIO 47 seeks passionate woman for discreet intimate encounters SEX
# le dad . 42 , East sub . 5 " 9 seeks woman 30 + for f / ship relationship TALL
# personal trainer looking for married woman age open for fun MARRIED Dark guy 37
# rinker , seeking slim - medium build woman who is happy in life , age open . AC
# . O . TERTIARY Educated professional woman , seeks professional , employed man
#  real romantic , age 50 - 65 y . o . WOMAN OF SUBSTANCE 56 , 59 kg ., 50 , fit

# %%
text8.concordance('female')
# Out:
# Displaying 15 of 15 matches:
# ingwood area , is seeking a genuine female of similar age or older , in same a
#  , dinner parties . Seeks out there female for friendship and fun . AUSSIE 39
# on smoker , light drinker . Seeking female friend , 40s , attractive 5 ft 5 +.
# at home . Seeking slim , attractive female , 20 - 30 with similar interests fo
# beach and the environment . Seeking female with similar interests to share con
# with varied interests seeks genuine female for friendship , relationship , and
# . 31 YO GUY Slim , Seeks 25 - 35 yo female for friendship / relationship , kid
# tgoing , genuine , friendly seeking female bet / w 30 - 35 yo , easygoing , fr
# NG LOVING & generous , seeks petite Female up to 38 . CARING well dressed rom
# 6yo MARRIED male seeks attr married female for discreet encounter . GENT , 30
#  Be mine . MALE 26 tall n / s seeks female early 30s for fun times South East
# like to meet attractive fit stylish female . For dinner and wine . Northcote M
# ...

# %%
text8.concordance('male', lines=42)
# Out:
# Displaying 42 of 42 matches:
#                                      MALE , seeks attrac older single lady , f
# - w / e away A professional business male , late 40s , 6 feet tall , slim buil
# ip . FIT ACTIVE EASYGOING 50 y . o . male , 6 ft 2 , med . build , fit and hea
# ship / relationship . GREEK / AUST . MALE Early 30s , 57 , slim build , non -
# dship view to permanent relationship MALE LATE 50 '' s AUST Single , tall , pr
# northern suburbs . TALL , ATTRACTIVE MALE 40s no ties , down to earth , easy g
# ip , kids ok . Eastern Suburbs 43 yo Male , blond , outgoing , genuine , frien
# roll , loves life , not in a hurry . MALE 58 years old . Is there a Woman who
# please write . Ref 8826 PROFESSIONAL Male , tall , fit , 40s , new to area who
# Caring thats me 2 . Attractive young male seek ing casual meetings with mature
# r suburbs Bright happy positive prof male 48 fit / healthy n / s seeks lady sa
# ...

# %%
text8.concordance('seeking')
# Out:
# Displaying 25 of 25 matches:
#                                     seeking lady in uniform for fun times . 40
# ll things good , Ringwood area , is seeking a genuine female of similar age or
# ties , non smoker , light drinker . Seeking female friend , 40s , attractive 5
# y drives and quiet nights at home . Seeking an honest , caring woman , slim or
# football and quiet nights at home . Seeking slim , attractive female , 20 - 30
# ocial drinker , fit and active , is seeking a slim - medium lady for friendship
# t , the beach and the environment . Seeking female with similar interests to sh
# ond , outgoing , genuine , friendly seeking female bet / w 30 - 35 yo , easygoi
# es cooking . GSOH , S / S , S / D , seeking F 45 - 55 for fship , poss rship ,
# ch , amongst many other interests . Seeking Christian Woman for fship , view to
# 37 for fship & rship GREEK GUY 46 , seeking Greek lady up to 50yo GREEK Male La
# ...

# %%
text8.concordance('relationship')
# Out:
# Displaying 25 of 29 matches:
# ts and music . View to permanent relationship . ATTRACTIVE GUY Late 30s , 57 ,
# to meet lady for friendship view relationship . AUSTRALIAN FATHER 58 With 11 y
#  genuine and good fun . Possible relationship . BEAUTIFUL , INTELLIGENT CARING
#  , honest lady for friendship to relationship . BUSINESSMAN 60 '' ish Looking
# ker , non smoker , for permanent relationship . FIT ACTIVE EASYGOING 50 y . o
# build . View towards a permanent relationship . Give me a call lets have a cha
# 8 - 45 for friendship / possible relationship . GENUINE ATTRACTIVE MAN 40 y .
# ircles . Age open , friendship / relationship . GREEK / AUST . MALE Early 30s
# ilar interests for friend ship / relationship . HANDSOME BUSINESSMAN Tall , sl
# is looking for a special private relationship . HERE I AM PICK ME ! PICK ME !
# m - medium lady for friendship / relationship . LIMESTONE COAST REGION Attract
# for friendship view to permanent relationship MALE LATE 50 '' s AUST Single ,
# ...

# %% [markdown]
# * Try some other words and examine concordance lines

# %% [markdown]
# #### Collocations
#
# * The `.collocations()` function returns a list of frequent/associated pairs of words.
#
#
# * `window_size` attribute controls the distance between words

# %%
text8.collocations(num=30)
# Out:
# would like; medium build; social drinker; quiet nights; non smoker;
# long term; age open; Would like; easy going; financially secure; fun
# times; similar interests; Age open; weekends away; poss rship; well
# presented; never married; single mum; permanent relationship; slim
# build; seeks lady; Late 30s; Photo pls; Vibrant personality; European
# background; year old; ASIAN LADY; country drives; intimate encounters;
# SINGLE DAD

# %%
text8.collocations(num=40, window_size=4)
# Out:
# non smoker; seeks lady; like meet; age open; social drinker; would
# like; quiet home; quiet nights; medium build; fship rship; long term;
# slim build; nights home; smoker drinker; med build; fun times; sense
# humour; smoker social; Would meet; easy going; Would like; poss rship;
# financially secure; similar interests; would meet; weekends away;
# friendship relationship; Age open; LADY sought; BALLROOM DANCING;
# DANCING PARTNER; well presented; never married; single mum; fship
# poss; slim medium; sim int; permanent relationship; Late 30s; Photo
# pls

# %% [markdown]
# ### Bigrams and Trigrams

# %%
personals_tokens=text8.tokens
personals_bigrams = ["{}_{}".format(personals_tokens[i], personals_tokens[i+1]) 
                                 for i in range(len(personals_tokens)-1)]

personals_trigrams = ["{}_{}_{}".format(personals_tokens[i], personals_tokens[i+1], personals_tokens[i+2]) 
                                 for i in range(len(personals_tokens)-2)]

# %%
from collections import Counter
pc_bigram_dist = Counter(personals_bigrams)
pc_trigram_dist = Counter(personals_trigrams)

# %%
pc_bigram_dist.most_common(30)
# Out:
# [('/_ship', 30),
#  ('._o', 25),
#  ('y_.', 23),
#  ('o_.', 21),
#  ('build_,', 20),
#  ('relationship_.', 20),
#  ('movies_,', 19),
#  (',_seeks', 18),
#  ('S_/', 18),
#  (',_movies', 17),
#  (',_non', 17),
#  ('/_S', 16),
#  ('like_to', 15),
#  ('to_meet', 15),
#  ('lady_for', 15),
#  ('r_/', 14),
#  (',_slim', 14),
#  ('smoker_,', 14),
#  (',_dining', 14),
#  ('lady_,', 13),
#  ('rship_.', 13),
#  (',_S', 13),
#  ('f_/', 13),
#  ('._Looking', 12),
#  ('looking_for', 12),
#  ('dining_out', 12),
#  ('Looking_for', 12),
#  ('/_D', 12),
#  ('non_-', 11),
#  ('._I', 11)]

# %%
pc_trigram_dist.most_common(30)
# Out:
# [('y_._o', 23),
#  ('._o_.', 21),
#  (',_movies_,', 15),
#  ('r_/_ship', 13),
#  (',_S_/', 13),
#  ('f_/_ship', 12),
#  ('like_to_meet', 11),
#  ('S_/_D', 11),
#  ('N_/_S', 10),
#  ('non_-_smoker', 9),
#  ('5_ft_.', 9),
#  ('._Looking_for', 9),
#  (',_non_-', 9),
#  ('non_smoker_,', 9),
#  ('/_S_,', 9),
#  (',_dining_out', 9),
#  ('for_f_/', 9),
#  ('would_like_to', 8),
#  ('medium_build_,', 7),
#  (',_music_,', 7),
#  (',_non_smoker', 7),
#  ('dining_out_,', 7),
#  ('S_,_S', 7),
#  ('/_D_,', 7),
#  ('._I_enjoy', 6),
#  ('quiet_nights_at', 6),
#  ('nights_at_home', 6),
#  (',_5_ft', 6),
#  ('S_/_S', 6),
#  ('n_/_s', 6)]

# %% [markdown]
# ## Flu discourse
#
# <img src="flu_psa.png" align="left" width=400/>

# %%
flu_text = '''
In the Flu Battle, Hydration and Elevation May Be Your Best Weapons

According to the misery map of influenza activity in the United States, there’s a good chance that you or someone you know has experienced, or will experience, the agony of this year’s strain, H3N2.

The map, from the Centers for Disease Control and Prevention, shows that it is a particularly wicked and widespread virus. And the current flu vaccine seems to be mismatched to the virus — in Australia, where flu season comes earlier, it was estimated to be only 10 percent effective.

Hospitals nationwide report clogged emergency rooms, and pharmacies are experiencing shortages of over-the-counter and prescription flu remedies. And we’re just at the start of the flu season, which doesn’t end until May.

Vulnerable patients with weakened immune systems should consult their doctors, as should anyone who begins to have trouble breathing or feels faint. But for otherwise healthy individuals, the best strategy is to understand how flu affects your body, and practice self-care accordingly.

Flu is spread predominantly by droplets in the air. So if you are within 3 to 6 feet of someone who is infected, you are likely to breathe in their germy exhalations. The virus will then latch onto the mucous membranes that line the back of your nose, your throat and your bronchial tubes. Next, the invaders hijack the epithelial cells that make up the mucous membranes, taking over their metabolic machinery, to replicate and make even more virus, which infects adjacent cells.

This initial phase takes one to four days. “The more you inhale, the shorter the incubation period,” said Dr. William Schaffner, an infectious disease specialist at Vanderbilt University School of Medicine in Nashville. “In the beginning, you don’t feel sick. You don’t even know it’s there.”

As the virus colonizes your respiratory tract, your body starts to figure out something is amiss and rallies its immunologic troops in an inflammatory response, releasing proteins called interferons — because they interfere with alien invaders. Interferons flood your bloodstream and set up camp in your mucus, prompting more proteins called cytokines to join the battle. These protein soldiers circulate throughout your body, ready to rumble.

“Paradoxically, our own soldiers created for the fight are what cause us to have symptoms,” said Dr. Schaffner.

“War creates damage and so you get fever and a headache and muscular aches and pains,” which you experience as the abrupt and intense opening salvos of the flu. These early symptoms are usually what distinguishes the flu from just a normal cold.

The achiness and fever also signal that you need to start drinking a lot of fluids. The battle royal being waged inside you will dehydrate you more than you think. You may notice that your urine will get darker and you’ll have to go less often. Experts say to make sure you drink a cup or so of water or other liquid every hour, avoiding alcoholic and caffeinated beverages.

Drinking fluids will diminish your headache and also bolster your immune response because your protein soldiers are conveyed via bodily fluids. Dehydration hampers their movement. It’s one reason people tend to want soup when they’re sick and may crave watery fruits like citrus and melon.

While you may feel rotten all over, the real battle is going on in your respiratory tract where the virus is localized. When the war is winding down, you stop feeling achy and feverish but you have residual inflammation in your throat, sinuses and bronchial tubes. All those cells lining your mucous membranes have been damaged and are like weeping sores, Dr. Schaffner said. That’s why your nose is runny and you start to sneeze and cough to clear out the detritus.

Given this, over-the-counter medications that suppress your cough and dry your sinuses may not be the best idea.

“Certainly there is the thought that you don’t want to suppress a cough too much or dry out your nasal passages because you want to get rid of the infection,” said Dr. Tara Vijayan, an assistant clinical professor in the division of infectious diseases at the University of California, Los Angeles, David Geffen School of Medicine. “There’s a balance for sure. I don’t think you should suffer unnecessarily, but you need to weigh the true benefit.”

Although you want to rest, lying flat all the time can be problematic because it collapses your lungs so you can’t cough as efficiently, trapping bacteria in your respiratory tract. If the virus destroys enough cells in your bronchial tubes it creates openings for bacteria to get into your lungs, which can lead to pneumonia, a potentially life-threatening complication of the flu.

When your lungs are vertical rather than horizontal, “you’re able to breathe deeply and freely and you’re able to cough out any inadvertent material, even microscopic bacteria, that get down into bronchial tubes,” Dr. Schaffner said.

The C.D.C. recommends people who are hospitalized or at high risk for complications of the flu, such as older patients, pregnant women and those who are otherwise immunocompromised, take the antiviral drug oseltamivir, sold under the brand name Tamiflu, because observational data indicate it might reduce the likelihood of death.

Other researchers, including those at the Cochrane Collaboration, disagree, saying that there’s not enough evidence to support taking oseltamivir or its chemical cousin zanamivir (brand name Relenza). They question the wisdom of spending billions stockpiling them as many countries, including the United States, began doing amid fears of a future flu pandemic in the mid 2000s. Indeed, the World Health Organization last year downgraded oseltamivir from its list of essential medicines. It may or may not help, depending on which study you look at.

For healthy people who get the flu, most researchers agree the data indicates oseltamivir taken within 48 hours of onset can reduce the duration by about two-thirds of a day. But at around $154 for a course of the medication, that may not be worth it, given that the side effects include nausea and vomiting.

“We wish we had better drugs that could wipe out flu,” said Angela Campbell, a medical officer with the C.D.C.’s Influenza Division. But she said oseltamivir is “what we have right now” and in outpatient situations “it’s really the clinician’s decision with the patient based on a number of factors,” including cost and effectiveness, whether it should be prescribed or not.

The C.D.C. also still recommends getting this season’s flu shot, despite its questionable prophylactic value, because it might reduce the severity of the flu should you contract it. In previous years, against strains other than H3N2, flu shots have had reported effectiveness of about 40 percent to 60 percent.

But beyond that, rest, fluids, not staying horizontal all day and perhaps also letting in fresh air and sunlight are the best things you can do for yourself. To prevent friends, family members and colleagues from getting sick, keep to yourself until 48 hours after your fever has subsided and you’re feeling better.

While you may continue to cough for weeks, Dr. Schaffner said you probably aren’t infectious. Just annoying.
'''

# %%
len(flu_text)
# Out:
# 7270

# %%
import string
rdict = str.maketrans('','',string.punctuation+'—')
tokens=flu_text.lower().translate(rdict).split()

# %%
from collections import Counter

# %%
word_dist = Counter(tokens)

# %%
word_dist.most_common()
# Out:
# [('the', 64),
#  ('and', 39),
#  ('to', 33),
#  ('you', 30),
#  ('your', 27),
#  ('of', 26),
#  ('in', 17),
#  ('flu', 16),
#  ('a', 14),
#  ('that', 14),
#  ('is', 11),
#  ('are', 11),
#  ('may', 10),
#  ('or', 10),
#  ('for', 10),
#  ('it', 10),
#  ('said', 8),
#  ('be', 7),
#  ('virus', 7),
#  ('at', 7),
#  ('have', 7),
#  ('as', 6),
#  ('but', 6),
#  ('dr', 6),
#  ('because', 6),
#  ('get', 6),
#  ('cough', 6),
#  ('not', 6),
#  ('will', 5),
#  ('which', 5),
#  ('should', 5),
#  ('who', 5),
#  ('schaffner', 5),
#  ('out', 5),
#  ('oseltamivir', 5),
#  ('battle', 4),
#  ('best', 4),
#  ('this', 4),
#  ('from', 4),
#  ('with', 4),
#  ('their', 4),
#  ('so', 4),
#  ('bronchial', 4),
#  ('cells', 4),
#  ('more', 4),
#  ('don’t', 4),
#  ('its', 4),
#  ('also', 4),
#  ('fluids', 4),
#  ('want', 4),
#  ('all', 4),
#  ('can', 4),
#  ('percent', 3),
#  ('just', 3),
#  ('start', 3),
#  ('body', 3),
#  ('mucous', 3),
#  ('membranes', 3),
#  ('tubes', 3),
#  ('make', 3),
#  ('even', 3),
# ...

# %%
bigram_dist = Counter(["{}_{}".format(tokens[i],tokens[i+1]) for i in range(len(tokens)-1)])
trigram_dist = Counter(["{}_{}_{}".format(tokens[i],tokens[i+1],tokens[i+2]) for i in range(len(tokens)-2)])

# %%
bigram_dist.most_common(50)
# Out:
# [('the_flu', 8),
#  ('of_the', 7),
#  ('in_the', 5),
#  ('the_virus', 5),
#  ('in_your', 5),
#  ('dr_schaffner', 4),
#  ('that_you', 3),
#  ('at_the', 3),
#  ('the_best', 3),
#  ('your_body', 3),
#  ('mucous_membranes', 3),
#  ('bronchial_tubes', 3),
#  ('said_dr', 3),
#  ('you_don’t', 3),
#  ('your_respiratory', 3),
#  ('respiratory_tract', 3),
#  ('you_may', 3),
#  ('schaffner_said', 3),
#  ('may_not', 3),
#  ('want_to', 3),
#  ('your_lungs', 3),
#  ('reduce_the', 3),
#  ('to_the', 2),
#  ('the_united', 2),
#  ('united_states', 2),
#  ('to_be', 2),
#  ('flu_season', 2),
#  ('to_have', 2),
#  ('you_are', 2),
#  ('to_breathe', 2),
#  ('the_mucous', 2),
#  ('your_nose', 2),
#  ('your_throat', 2),
#  ('your_bronchial', 2),
#  ('school_of', 2),
#  ('of_medicine', 2),
#  ('as_the', 2),
#  ('proteins_called', 2),
#  ('the_battle', 2),
#  ('protein_soldiers', 2),
#  ('so_you', 2),
#  ('headache_and', 2),
#  ('you_need', 2),
#  ('need_to', 2),
#  ('think_you', 2),
#  ('while_you', 2),
# ...

# %%
trigram_dist.most_common(50)
# Out:
# [('of_the_flu', 5),
#  ('your_respiratory_tract', 3),
#  ('dr_schaffner_said', 3),
#  ('the_united_states', 2),
#  ('the_mucous_membranes', 2),
#  ('your_bronchial_tubes', 2),
#  ('school_of_medicine', 2),
#  ('you_need_to', 2),
#  ('while_you_may', 2),
#  ('in_your_respiratory', 2),
#  ('may_not_be', 2),
#  ('you_want_to', 2),
#  ('it_might_reduce', 2),
#  ('might_reduce_the', 2),
#  ('in_the_flu', 1),
#  ('the_flu_battle', 1),
#  ('flu_battle_hydration', 1),
#  ('battle_hydration_and', 1),
#  ('hydration_and_elevation', 1),
#  ('and_elevation_may', 1),
#  ('elevation_may_be', 1),
#  ('may_be_your', 1),
#  ('be_your_best', 1),
#  ('your_best_weapons', 1),
#  ('best_weapons_according', 1),
#  ('weapons_according_to', 1),
#  ('according_to_the', 1),
#  ('to_the_misery', 1),
#  ('the_misery_map', 1),
#  ('misery_map_of', 1),
#  ('map_of_influenza', 1),
#  ('of_influenza_activity', 1),
#  ('influenza_activity_in', 1),
#  ('activity_in_the', 1),
#  ('in_the_united', 1),
# ...

# %% [markdown]
# ## Building a specialized corpus
#
# ### Example: Using _LexisNexis_

# %%
ls /data/flu/flu_news_corpus/
# Out:
# flu_text100_2008.txt  flu_text399_2013.txt  flu_text698_2015.txt
# flu_text101_2008.txt  flu_text400_2013.txt  flu_text699_2015.txt
# flu_text10_1998.txt   flu_text401_2013.txt  flu_text700_2015.txt
# flu_text102_2008.txt  flu_text40_2005.txt   flu_text701_2015.txt
# flu_text103_2008.txt  flu_text402_2013.txt  flu_text70_2006.txt
# flu_text104_2008.txt  flu_text403_2013.txt  flu_text702_2015.txt
# flu_text105_2008.txt  flu_text404_2013.txt  flu_text703_2015.txt
# flu_text106_2008.txt  flu_text405_2013.txt  flu_text704_2015.txt
# flu_text107_2008.txt  flu_text406_2013.txt  flu_text705_2015.txt
# flu_text108_2008.txt  flu_text407_2013.txt  flu_text706_2015.txt
# flu_text109_2008.txt  flu_text408_2013.txt  flu_text707_2015.txt
# flu_text110_2008.txt  flu_text409_2013.txt  flu_text708_2015.txt
# flu_text111_2008.txt  flu_text410_2013.txt  flu_text709_2015.txt
# flu_text11_1998.txt   flu_text411_2013.txt  flu_text710_2015.txt
# ...

# %%
docs = [open('/data/flu/flu_news_corpus/{}'.format(f)).read() for f in os.listdir('/data/flu/flu_news_corpus')]

# %%
ln_flu_corpus = '\n\n'.join(docs)

# %%
ln_flu_tokens = ln_flu_corpus.lower().translate(rdict).split()

# %%
len(ln_flu_tokens)
# Out:
# 624466

# %%
ln_flu_words = Counter(ln_flu_tokens)

# %%
ln_flu_words.most_common(100)
# Out:
# [('the', 32900),
#  ('of', 16019),
#  ('and', 15515),
#  ('flu', 15478),
#  ('to', 14775),
#  ('a', 11427),
#  ('in', 10735),
#  ('influenza', 9777),
#  ('is', 8396),
#  ('for', 6309),
#  ('are', 5532),
#  ('that', 4988),
#  ('with', 4732),
#  ('or', 4220),
#  ('vaccine', 4181),
#  ('people', 4129),
#  ('as', 3937),
#  ('health', 3880),
#  ('said', 3878),
#  ('this', 3658),
#  ('from', 3650),
#  ('it', 3554),
#  ('have', 3550),
#  ('be', 3407),
#  ('at', 3406),
#  ('virus', 3028),
#  ('not', 2929),
#  ('by', 2730),
#  ('season', 2674),
#  ('can', 2505),
#  ('year', 2485),
#  ('you', 2290),
#  ('get', 2148),
#  ('has', 2137),
#  ('who', 2114),
#  ('cases', 2009),
#  ('but', 2003),
#  ('on', 1989),
#  ('swine', 1967),
#  ('an', 1957),
#  ('been', 1951),
#  ('more', 1913),
#  ('all', 1879),
#  ('viruses', 1774),
#  ('shot', 1663),
#  ('there', 1652),
#  ('your', 1567),
#  ('if', 1560),
#  ('its', 1559),
#  ('they', 1516),
#  ('also', 1512),
#  ('against', 1492),
#  ('symptoms', 1482),
# ...

# %%
ln_bigrams = ["{}_{}".format(ln_flu_tokens[i], ln_flu_tokens[i+1]) 
                  for i in range(len(ln_flu_tokens)-1)]

# %%
ln_bigrams_dist = Counter(ln_bigrams)

# %%
ln_bigrams_dist.most_common(50)
# Out:
# [('the_flu', 4140),
#  ('of_the', 3248),
#  ('in_the', 2684),
#  ('swine_flu', 1541),
#  ('flu_season', 1485),
#  ('flu_vaccine', 1475),
#  ('to_the', 1465),
#  ('of_influenza', 1465),
#  ('flu_shot', 1364),
#  ('influenza_a', 1045),
#  ('the_vaccine', 1010),
#  ('language_english', 995),
#  ('for_the', 944),
#  ('to_be', 938),
#  ('it_is', 925),
#  ('to_get', 918),
#  ('of_flu', 908),
#  ('the_virus', 870),
#  ('publicationtype_newspaper', 863),
#  ('a_flu', 856),
#  ('have_been', 849),
#  ('all_rights', 832),
#  ('rights_reserved', 832),
#  ('the_influenza', 828),
#  ('with_the', 814),
#  ('is_a', 813),
#  ('from_the', 765),
#  ('and_the', 746),
#  ('this_year', 736),
#  ('at_the', 714),
#  ('flu_is', 664),
#  ('according_to', 647),
#  ('public_health', 642),
#  ('such_as', 639),
#  ('people_who', 622),
#  ('influenza_virus', 613),
#  ('number_of', 611),
#  ('seasonal_flu', 611),
#  ('english_publicationtype', 610),
#  ('is_the', 586),
#  ('cases_of', 580),
#  ('by_the', 568),
# ...

# %%
ln_flu_words['mucus'], ln_flu_words['mucous']
# Out:
# (6, 1)

# %%
len(docs)
# Out:
# 995

# %%
ln_flu_words['nose']
# Out:
# 540

# %%
def make_kwic(kw, text, win=4):
    '''A basic KWIC function for a text
    
    Args:
        kw   -- string match for keyword to match for each line
        text -- a list of tokens for the text
        
    Return:
        list of lines of form [ [left context words], kw, [right context words]]
    '''
    
    hits = [(w,i) for i,w in enumerate(text) if w==kw]
    
    lines = []
    for hit in hits:
        left = text[hit[1]-win:hit[1]]
        kw = text[hit[1]]
        right = text[hit[1]+1 : hit[1]+win+1]
        
        lines.append([left, kw, right])
        
    return lines

# %%
def print_kwic(kwic, win=None):
    '''A basic print function for a KWIC object
    
    Args:
        kwic -- a list of KWIC lines of the form [ [left words], kw, [right words]]
        win  -- if None then use all words provided in context otherwise limit by win
        
    Prints KWIC lines with left context width/padding win*8 characters
    '''
    
    if not kwic:
        return
    
    if win is None:
        win = len(kwic[0][0])
    
    for line in kwic:
        print("{:>{}}  {}  {}".format(' '.join(line[0][-win:]), 
                                      win*8, 
                                      line[1], 
                                      ' '.join(line[2][:win])
                                     )
             )

# %%
fight = make_kwic('fight',ln_flu_tokens)
fight.sort(key=lambda x: x[2])
print_kwic(fight, win=4)
# Out:
#      typically contain agents to  fight  a combination of a
# different from antibiotics which  fight  against bacterial infections private
#           week to coordinate the  fight  against bird flu documenttype
#                allow the body to  fight  against flu the needle
#        current research work the  fight  against influenza involves professionals
#        current research work the  fight  against influenza involves professionals
#         effective weapons in the  fight  against influenza which kills
#    important contribution to the  fight  against influenza which makes
#    important contribution to the  fight  against influenza which makes
#    important contribution to the  fight  against influenza which makes
#    important contribution to the  fight  against influenza which makes
#    important contribution to the  fight  against influenza which makes
#           virus meanwhile in its  fight  against the disease serum
# ...

# %%
print_kwic(sorted(make_kwic('season',ln_flu_tokens), key=lambda x:x[0][-1]))
# Out:
#              676 words jan 09flu  season  is here and officials
#              643 words oct 15flu  season  is well on the
#            set during the 200304  season  the official numbers likely
#              for the entire 2005  season  while publicity about the
#        example during the 200607  season  only 444 were immunized
#          expected for the 200607  season  though ive learned to
#            but way behind 200910  season  byline by kevin b
#     considerably from the 200910  season  marked by the arrival
#          point during the 200910  season  though this flu season
#          typical than the 200910  season  influenzaassociated deaths and hospitalizations
#    circulating during the 200910  season  infectious disease experts said
#        vaccine during the 200910  season  the nation fell millions
#            period for the 200910  season  time period hospitalizations deaths
#      employees during the 200910  season  said jorge parada md
# ...

# %%
def get_collocates(kw,token_dict, span=4):
    ''' Create a frequency list of the collocates of a specified keyword in a corpus of texts
    
    Args:
        kw         -- keyword to use as center of analysis
        token_dict -- corpus in the form of a dictionary of tokenized texts where a text is a list of tokens
        span       --
        
    Returns:
    
        Frequency list of collocates in a Counter object 
    '''
    collocates = Counter()
    for speech, tokens in token_dict.items():
        hits = [i for i,w in enumerate(tokens) if w==kw]
        for i in hits:
            collocates.update(tokens[i-span:i] + tokens[i+1:span+1] )
        
    return collocates

# %%
fight_colls=get_collocates('fight', {'corpus': ln_flu_tokens}, span=4)
fight_colls.most_common()
# Out:
# [('to', 56),
#  ('the', 25),
#  ('and', 7),
#  ('can', 7),
#  ('body', 7),
#  ('help', 6),
#  ('important', 6),
#  ('in', 6),
#  ('you', 5),
#  ('most', 5),
#  ('contribution', 5),
#  ('antibodies', 5),
#  ('vaccine', 4),
#  ('bodys', 4),
#  ('that', 4),
#  ('ability', 3),
#  ('woman', 3),
#  ('immunity', 3),
#  ('6', 3),
#  ('2017', 3),
#  ('friday', 3),
#  ('will', 3),
#  ('we', 3),
#  ('make', 3),
#  ('effective', 3),
#  ('way', 3),
#  ('take', 3),
#  ('an', 3),
#  ('your', 3),
#  ('developed', 2),
#  ('washington', 2),
#  ('into', 2),
#  ('play', 2),
#  ('have', 2),
#  ('flu', 2),
#  ('shot', 2),
#  ('antibody', 2),
#  ('action', 2),
#  ('antiviral', 2),
#  ('or', 2),
#  ('inhaler', 2),
#  ('immune', 2),
#  ('system', 2),
#  ('virus', 2),
#  ('our', 2),
#  ('bodies', 2),
#  ('2016', 2),
#  ('final', 2),
#  ('edition', 2),
#  ('current', 2),
#  ('research', 2),
#  ('work', 2),
#  ('is', 2),
#  ('vaccination', 2),
#  ('rates', 2),
#  ('get', 2),
#  ('inhaled', 1),
# ...

# %%
get_collocates('season', {'corpus': ln_flu_tokens}, span=4).most_common()
# Out:
# [('flu', 1626),
#  ('the', 1283),
#  ('this', 567),
#  ('influenza', 345),
#  ('of', 321),
#  ('during', 309),
#  ('a', 228),
#  ('in', 196),
#  ('for', 179),
#  ('last', 130),
#  ('years', 113),
#  ('to', 96),
#  ('and', 88),
#  ('so', 68),
#  ('severe', 67),
#  ('be', 60),
#  ('words', 60),
#  ('far', 58),
#  ('from', 57),
#  ('that', 57),
#  ('before', 56),
#  ('said', 55),
#  ('vaccine', 54),
#  ('as', 54),
#  ('each', 53),
#  ('early', 51),
#  ('peak', 49),
#  ('season', 46),
#  ('cases', 46),
#  ('is', 44),
#  ('start', 41),
#  ('year', 41),
#  ('circulating', 40),
#  ('upcoming', 39),
#  ('its', 38),
#  ('common', 35),
#  ('one', 35),
#  ('with', 35),
#  ('vaccinated', 34),
#  ('throughout', 33),
#  ('every', 32),
#  ('since', 31),
#  ('typical', 31),
#  ('current', 30),
#  ('edition', 30),
#  ('20142015', 29),
#  ('winter', 29),
#  ('an', 28),
#  ('been', 27),
#  ('20132014', 26),
#  ('200910', 25),
#  ('next', 25),
#  ('have', 22),
#  ('length', 22),
#  ('virus', 21),
# ...

# %%
def plot_collocates(kw, collocate_list, num=20, show_freq=False, title=None, threshold=1):
    ''' Create a graph of the collocates of a keyword within a specified window and threshold
    
    Args:
        kw              -- keyword to place at center of graph
        collocate_list  -- Counter object of collocate frequencies
        num             -- the number of collocates (in descending frequency to display) [default=20]
        show_freq       -- whether to show frequency beside edge True/False [default=False]
        title           -- string to use as a title for the plot [default=None]
        threshold       -- frequency threshold for showing edges [default=1]
        
    '''
    cG = graphviz.Graph(engine='neato')
    cG.attr('graph', overlap='scalexy', size="8,8")
    if title:
        cG.attr('graph', label=title, labelloc='t', fontsize='20')
    for item, freq in collocate_list.most_common(num):
        if freq >= threshold:
            cG.edge(kw.upper(), item, penwidth=str(math.log(freq/10,2)+1), 
                    label=None if not show_freq else str(freq))
    
    return cG

# %%
season = get_collocates('vaccine', {'corpus': ln_flu_tokens}, span=2)
plot_collocates('vaccine', season, show_freq=True)
